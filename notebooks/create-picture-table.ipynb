# %%
import pandas as pd
from pathlib import Path

data = {
    "continent": [
        "Africa",
        "Asia",
        "Europe",
        "North America",
        "Oceania",
        "South America",
        "Worldwide"
    ],
    "picture_url": [
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_4.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_6.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_5.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_2.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_1.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_3.png",
        "https://raw.githubusercontent.com/JohnnyHyytiainen/DEUX2025_music_project/feat/create-picture-table/assets/pictures/Knob_0.png"
    ]
}

df = pd.DataFrame(data)
data_path = Path.cwd().parent / 'data'

df.to_csv(data_path / "continents_pictures.csv", index=False, encoding="utf-8-sig")

print("CSV-file have been created")
# Out:
# CSV-file have been created

# %%
df
# Out:
#        continent                                        picture_url
# 0         Africa  https://raw.githubusercontent.com/JohnnyHyytia...
# 1           Asia  https://raw.githubusercontent.com/JohnnyHyytia...
# 2         Europe  https://raw.githubusercontent.com/JohnnyHyytia...
# 3  North America  https://raw.githubusercontent.com/JohnnyHyytia...
# 4        Oceania  https://raw.githubusercontent.com/JohnnyHyytia...
# 5  South America  https://raw.githubusercontent.com/JohnnyHyytia...
# 6      Worldwide  https://raw.githubusercontent.com/JohnnyHyytia...
